# %% [markdown]
# ## Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import math 
from random import random 
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from pathlib import Path 
import librosa 
import json 
from collections import defaultdict

# %% [markdown]
# ## Set up GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(f"Device: {device}")
# Out:
# Device: mps

# %% [markdown]
# ## Data

# %% [markdown]
# ### KAGGLE GTZAN Dataset

# %%
from dotenv import load_dotenv 
load_dotenv() 
import kagglehub 

download_path = Path(kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification"))

print(f"download path: {download_path}")
print(f"data contents: {list(download_path.iterdir())}")
# Out:
# download path: /Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1
# data contents: [PosixPath('/Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1/Data')]

# %% [markdown]
# ### Constants

# %%
SAMPLE_RATE = 22050
DURATION = 30  # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %% [markdown]
# ### MFCC Data Preprocessing

# %%
from tqdm import tqdm 

def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    # dictionary to store data
    data = {
        # genres
        "mapping": [],
        # mfcc vectors for each of the segments - the training inputs
        "mfcc": [],
        # the target variables
        "labels": [],
    }
 
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)  # 1.2 => 2
 
    # loop through all the genre folders (one level down from dataset_path)
    # sorted() makes the label order deterministic across machines
    genre_dirs = sorted(p for p in dataset_path.iterdir() if p.is_dir())
 
    for i, genre_dir in enumerate(genre_dirs):
        # save the semantic label (e.g. "blues")
        semantic_label = genre_dir.name
        data["mapping"].append(semantic_label)
        # .glob("*.wav") automatically skips hidden files like .DS_Store
        wav_files = sorted(genre_dir.glob("*.wav"))
 
        # process all wav files for current genre
        for file_path in tqdm(wav_files, desc=f"{semantic_label:10s}", leave=True):
            # some GTZAN files are corrupted (e.g. jazz.00054) - skip them
            try:
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
            except Exception as e:
                tqdm.write(f"Skipping corrupted file {file_path.name}")
                continue
 
            # process segments extracting mfcc and storing data
            # s - current segment we are in. slide to the right the number of samples per segment
            for s in range(num_segments):
                start_sample = num_samples_per_segment * s  # s=0 => 0
                end_sample = start_sample + num_samples_per_segment # s=0 => num_samples_per_segment

                # returns a matrix (mfcc, time)
                mfcc = librosa.feature.mfcc(
                    y=signal[start_sample:end_sample],
                    sr=sr,
                    n_fft=n_fft,
                    n_mfcc=n_mfcc,
                    hop_length=hop_length,
                )

                # convert to (time, mfcc) for deep learning 
                mfcc = mfcc.T
 
                # store mfcc for segment if it has the expected length
                if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i)
 
    # make sure the output directory exists before writing
    json_path.parent.mkdir(parents=True, exist_ok=True)
 
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
json_path = Path("data/mfcc_data.json")
dataset_path = download_path / "Data" / "genres_original"
save_mfcc(dataset_path, json_path, num_segments=10)
# Out:
# blues     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 36.72it/s]
# classical : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.52it/s]
# country   : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 47.99it/s]
# disco     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 47.52it/s]
# hiphop    : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 49.63it/s]
# jazz      :  53%|███████████████████████████▌                        | 53/100 [00:01<00:00, 49.66it/s]/var/folders/73/y8z3_15n0c3fnwk5fkhj6ql40000gn/T/ipykernel_9988/2706401927.py:32: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
# /Users/pranavrajan/Desktop/ml-engineering-practice/.venv/lib/python3.10/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# jazz      :  58%|██████████████████████████████▏                     | 58/100 [00:01<00:01, 36.44it/s]
# Skipping corrupted file jazz.00054.wav
# jazz      : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 44.57it/s]
# metal     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 49.56it/s]
# pop       : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.03it/s]
# reggae    : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 47.58it/s]
# rock      : 100%|███████████████████████████████████████████████████| 100/100 [00:01<00:00, 50.05it/s]

# %% [markdown]
# ## Dataset Processing

# %%
import json 

# load data 
def load_data(dataset_path):
    with open(dataset_path, "r") as f:
        data = json.load(f)

    # convert lists into numpy arrays 
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    
    return inputs, targets

# %%
# split the data into train and test sets
inputs, targets = load_data(json_path)
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

input_train = torch.from_numpy(inputs_train).float()
input_test = torch.from_numpy(inputs_test).float()
target_train = torch.from_numpy(targets_train).long()
target_test = torch.from_numpy(targets_test).long()

train_dataset = TensorDataset(input_train, target_train)
test_dataset = TensorDataset(input_test, target_test)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ## Neural Network Architecture - Multi-Layer Perceptron(MLP)

# %%
# neural network architecture 
class MusicGenreClassifier(nn.Module):
    def __init__(self, time_steps, n_mfcc, num_classes=10):
        super().__init__()
        # build a model 
        self.net = nn.Sequential(
            # input layer 
            # convert everything into one vetor(batch, time_steps * n_mfcc)
            nn.Flatten(),

            # 1st layer 
            nn.Linear(time_steps * n_mfcc, 512),
            nn.ReLU(),

            # 2nd layer 
            nn.Linear(512, 256),
            nn.ReLU(),

            # 3rd layer 
            nn.Linear(256, 64),
            nn.ReLU(),

            # output layer 
            nn.Linear(64, num_classes)
        )
    def forward(self, x):
        return self.net(x)

def train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50):
    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0
        for x_batch, y_batch in train_dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            # run forward pass 
            preds = model(x_batch)
            # run cross entropy loss 
            loss = loss_fn(preds, y_batch)
            # run backward pass 
            loss.backward()
            # update parameters 
            optimizer.step()

            # accumulate training loss 
            train_loss    += loss.item() * x_batch.size(0)
            
            # number of correct predictions in batch 
            train_correct += (preds.argmax(1) == y_batch).sum().item()

            # number of samples in the batch 
            train_total   += y_batch.size(0)

        # check the model accuracy once per epoch on the test data 
        test_loss, test_acc = evaluate(model, test_dataloader, loss_fn, device)

        # update the training statistics 
        history["train_loss"].append(train_loss / train_total)
        history["train_acc"].append(train_correct / train_total)
        history["test_loss"].append(test_loss)
        history["test_acc"].append(test_acc)

        print(
            f"Epoch {epoch + 1}/{epochs} | "
            f"train_loss: {train_loss / train_total:.4f} - train_acc: {train_correct / train_total:.4f} | "
            f"test_loss: {test_loss:.4f} - test_acc: {test_acc:.4f}"
        )
        
    print("---------------------------------------")
    print("Training Finished!\n")


def evaluate(model, dataloader, loss_fn, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            preds = model(x_batch)
            loss = loss_fn(preds, y_batch)
            total_loss += loss.item() * x_batch.size(0)
            correct    += (preds.argmax(1) == y_batch).sum().item()
            total      += y_batch.size(0)

    return total_loss / total, correct / total

# %%
# compile network 
model = MusicGenreClassifier(inputs.shape[1], inputs.shape[2]).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.CrossEntropyLoss()

# train network 
history = defaultdict(list)
train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50)
# Out:
# Epoch 1/50 | train_loss: 1.6044 - train_acc: 0.4255 | test_loss: 1.3864 - test_acc: 0.5164
# Epoch 2/50 | train_loss: 1.2500 - train_acc: 0.5491 | test_loss: 1.2933 - test_acc: 0.5374
# Epoch 3/50 | train_loss: 1.1032 - train_acc: 0.6073 | test_loss: 1.2002 - test_acc: 0.5731
# Epoch 4/50 | train_loss: 0.9503 - train_acc: 0.6710 | test_loss: 1.2222 - test_acc: 0.5611
# Epoch 5/50 | train_loss: 0.8479 - train_acc: 0.7037 | test_loss: 1.1644 - test_acc: 0.5925
# Epoch 6/50 | train_loss: 0.7572 - train_acc: 0.7326 | test_loss: 1.1574 - test_acc: 0.6091
# Epoch 7/50 | train_loss: 0.6500 - train_acc: 0.7813 | test_loss: 1.2137 - test_acc: 0.5938
# Epoch 8/50 | train_loss: 0.5774 - train_acc: 0.8056 | test_loss: 1.1208 - test_acc: 0.6275
# Epoch 9/50 | train_loss: 0.4959 - train_acc: 0.8385 | test_loss: 1.1981 - test_acc: 0.6138
# Epoch 10/50 | train_loss: 0.4256 - train_acc: 0.8627 | test_loss: 1.1668 - test_acc: 0.6379
# Epoch 11/50 | train_loss: 0.3883 - train_acc: 0.8711 | test_loss: 1.1682 - test_acc: 0.6415
# Epoch 12/50 | train_loss: 0.3319 - train_acc: 0.8954 | test_loss: 1.1929 - test_acc: 0.6395
# Epoch 13/50 | train_loss: 0.2952 - train_acc: 0.9063 | test_loss: 1.2080 - test_acc: 0.6512
# Epoch 14/50 | train_loss: 0.2331 - train_acc: 0.9288 | test_loss: 1.2925 - test_acc: 0.6375
# Epoch 15/50 | train_loss: 0.2088 - train_acc: 0.9340 | test_loss: 1.2473 - test_acc: 0.6485
# Epoch 16/50 | train_loss: 0.1816 - train_acc: 0.9458 | test_loss: 1.3078 - test_acc: 0.6318
# Epoch 17/50 | train_loss: 0.1609 - train_acc: 0.9516 | test_loss: 1.3209 - test_acc: 0.6522
# Epoch 18/50 | train_loss: 0.1404 - train_acc: 0.9608 | test_loss: 1.3800 - test_acc: 0.6502
# Epoch 19/50 | train_loss: 0.1294 - train_acc: 0.9618 | test_loss: 1.5362 - test_acc: 0.6215
# Epoch 20/50 | train_loss: 0.1686 - train_acc: 0.9481 | test_loss: 1.4406 - test_acc: 0.6542
# Epoch 21/50 | train_loss: 0.0930 - train_acc: 0.9740 | test_loss: 1.4613 - test_acc: 0.6545
# Epoch 22/50 | train_loss: 0.0816 - train_acc: 0.9773 | test_loss: 1.5810 - test_acc: 0.6399
# Epoch 23/50 | train_loss: 0.0762 - train_acc: 0.9803 | test_loss: 1.5285 - test_acc: 0.6512
# Epoch 24/50 | train_loss: 0.0670 - train_acc: 0.9843 | test_loss: 1.6149 - test_acc: 0.6445
# Epoch 25/50 | train_loss: 0.0599 - train_acc: 0.9845 | test_loss: 1.6503 - test_acc: 0.6545
# Epoch 26/50 | train_loss: 0.0668 - train_acc: 0.9795 | test_loss: 1.6103 - test_acc: 0.6525
# Epoch 27/50 | train_loss: 0.0976 - train_acc: 0.9712 | test_loss: 1.7255 - test_acc: 0.6325
# Epoch 28/50 | train_loss: 0.1142 - train_acc: 0.9655 | test_loss: 1.6538 - test_acc: 0.6525
# Epoch 29/50 | train_loss: 0.0725 - train_acc: 0.9798 | test_loss: 1.5307 - test_acc: 0.6779
# Epoch 30/50 | train_loss: 0.0207 - train_acc: 0.9969 | test_loss: 1.5828 - test_acc: 0.6829
# Epoch 31/50 | train_loss: 0.0179 - train_acc: 0.9973 | test_loss: 1.6450 - test_acc: 0.6856
# Epoch 32/50 | train_loss: 0.0744 - train_acc: 0.9750 | test_loss: 1.9507 - test_acc: 0.6268
# Epoch 33/50 | train_loss: 0.1174 - train_acc: 0.9638 | test_loss: 1.6652 - test_acc: 0.6609
# Epoch 34/50 | train_loss: 0.0572 - train_acc: 0.9821 | test_loss: 1.7679 - test_acc: 0.6646
# Epoch 35/50 | train_loss: 0.0642 - train_acc: 0.9797 | test_loss: 1.7647 - test_acc: 0.6592
# Epoch 36/50 | train_loss: 0.0213 - train_acc: 0.9953 | test_loss: 1.6627 - test_acc: 0.6816
# Epoch 37/50 | train_loss: 0.1014 - train_acc: 0.9700 | test_loss: 1.8672 - test_acc: 0.6265
# Epoch 38/50 | train_loss: 0.0981 - train_acc: 0.9704 | test_loss: 1.7731 - test_acc: 0.6642
# Epoch 39/50 | train_loss: 0.0230 - train_acc: 0.9946 | test_loss: 1.8273 - test_acc: 0.6696
# Epoch 40/50 | train_loss: 0.0191 - train_acc: 0.9960 | test_loss: 1.6798 - test_acc: 0.6906
# Epoch 41/50 | train_loss: 0.0103 - train_acc: 0.9977 | test_loss: 1.8383 - test_acc: 0.6702
# Epoch 42/50 | train_loss: 0.0156 - train_acc: 0.9969 | test_loss: 1.7416 - test_acc: 0.6869
# Epoch 43/50 | train_loss: 0.0737 - train_acc: 0.9781 | test_loss: 2.0465 - test_acc: 0.6085
# Epoch 44/50 | train_loss: 0.1634 - train_acc: 0.9443 | test_loss: 1.9487 - test_acc: 0.6238
# Epoch 45/50 | train_loss: 0.0557 - train_acc: 0.9825 | test_loss: 1.7580 - test_acc: 0.6709
# Epoch 46/50 | train_loss: 0.0103 - train_acc: 0.9984 | test_loss: 1.6618 - test_acc: 0.6939
# Epoch 47/50 | train_loss: 0.0067 - train_acc: 0.9986 | test_loss: 1.7419 - test_acc: 0.6849
# Epoch 48/50 | train_loss: 0.0049 - train_acc: 0.9993 | test_loss: 1.7545 - test_acc: 0.6933
# Epoch 49/50 | train_loss: 0.0074 - train_acc: 0.9981 | test_loss: 1.8371 - test_acc: 0.6786
# Epoch 50/50 | train_loss: 0.0092 - train_acc: 0.9977 | test_loss: 1.8902 - test_acc: 0.6819
# ---------------------------------------
# Training Finished!

# %% [markdown]
# ## Plot Results

# %%
def plot_history(history):
    fig, axs = plt.subplots(2, figsize=(10, 8))
    
    # create accuracy subplot 
    axs[0].plot(history["train_acc"], label="train accuracy")
    axs[0].plot(history["test_acc"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="best")
    axs[0].set_title("Accuracy eval")

    # create error subplot 
    axs[1].plot(history["train_loss"], label="train error")
    axs[1].plot(history["test_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="best")
    axs[1].set_title("Error eval")

    fig.tight_layout()
    plt.show()

# %%
# plot accuracy and error over the epochs 
plot_history(history)

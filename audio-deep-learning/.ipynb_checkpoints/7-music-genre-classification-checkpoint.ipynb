# %% [markdown]
# ## Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import math 
from random import random 
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from pathlib import Path 
import librosa 
import json

# %% [markdown]
# ## Set up GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(f"Device: {device}")
# Out:
# Device: mps

# %% [markdown]
# ## Data

# %% [markdown]
# ### KAGGLE GTZAN Dataset

# %%
from dotenv import load_dotenv 
load_dotenv() 
import kagglehub 

download_path = Path(kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification"))

print(f"download path: {download_path}")
print(f"data contents: {list(download_path.iterdir())}")
# Out:
# download path: /Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1
# data contents: [PosixPath('/Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1/Data')]

# %% [markdown]
# ### Constants

# %%
SAMPLE_RATE = 22050
DURATION = 30  # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %% [markdown]
# ### MFCC Data Preprocessing

# %%
from tqdm import tqdm 

def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    # dictionary to store data
    data = {
        # genres
        "mapping": [],
        # mfcc vectors for each of the segments - the training inputs
        "mfcc": [],
        # the target variables
        "labels": [],
    }
 
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)  # 1.2 => 2
 
    # loop through all the genre folders (one level down from dataset_path)
    # sorted() makes the label order deterministic across machines
    genre_dirs = sorted(p for p in dataset_path.iterdir() if p.is_dir())
 
    for i, genre_dir in enumerate(genre_dirs):
        # save the semantic label (e.g. "blues")
        semantic_label = genre_dir.name
        data["mapping"].append(semantic_label)
        # .glob("*.wav") automatically skips hidden files like .DS_Store
        wav_files = sorted(genre_dir.glob("*.wav"))
 
        # process all wav files for current genre
        for file_path in tqdm(wav_files, desc=f"{semantic_label:10s}", leave=True):
            # some GTZAN files are corrupted (e.g. jazz.00054) - skip them
            try:
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
            except Exception as e:
                tqdm.write(f"Skipping corrupted file {file_path.name}")
                continue
 
            # process segments extracting mfcc and storing data
            # s - current segment we are in. slide to the right the number of samples per segment
            for s in range(num_segments):
                start_sample = num_samples_per_segment * s  # s=0 => 0
                end_sample = start_sample + num_samples_per_segment # s=0 => num_samples_per_segment

                # returns a matrix (mfcc, time)
                mfcc = librosa.feature.mfcc(
                    y=signal[start_sample:end_sample],
                    sr=sr,
                    n_fft=n_fft,
                    n_mfcc=n_mfcc,
                    hop_length=hop_length,
                )

                # convert to (time, mfcc) for deep learning 
                mfcc = mfcc.T
 
                # store mfcc for segment if it has the expected length
                if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i)
 
    # make sure the output directory exists before writing
    json_path.parent.mkdir(parents=True, exist_ok=True)
 
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
json_path = Path("data/mfcc_data.json")
dataset_path = download_path / "Data" / "genres_original"
save_mfcc(dataset_path, json_path, num_segments=10)
# Out:
# blues     : 100%|██████████████████████████████████████████████████████| 100/100 [00:04<00:00, 24.46it/s]
# classical : 100%|██████████████████████████████████████████████████████| 100/100 [00:03<00:00, 33.14it/s]
# country   : 100%|██████████████████████████████████████████████████████| 100/100 [00:03<00:00, 33.04it/s]
# disco     : 100%|██████████████████████████████████████████████████████| 100/100 [00:03<00:00, 33.09it/s]
# hiphop    : 100%|██████████████████████████████████████████████████████| 100/100 [00:02<00:00, 35.00it/s]
# jazz      :  52%|████████████████████████████▌                          | 52/100 [00:01<00:01, 35.15it/s]/var/folders/73/y8z3_15n0c3fnwk5fkhj6ql40000gn/T/ipykernel_7844/2706401927.py:32: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
# /Users/pranavrajan/Desktop/ml-engineering-practice/.venv/lib/python3.10/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# jazz      :  60%|█████████████████████████████████                      | 60/100 [00:01<00:01, 24.30it/s]
# Skipping corrupted file jazz.00054.wav
# jazz      : 100%|██████████████████████████████████████████████████████| 100/100 [00:03<00:00, 29.80it/s]
# metal     : 100%|██████████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.91it/s]
# pop       : 100%|██████████████████████████████████████████████████████| 100/100 [00:03<00:00, 32.28it/s]
# reggae    : 100%|██████████████████████████████████████████████████████| 100/100 [00:02<00:00, 35.10it/s]
# rock      : 100%|██████████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.35it/s]

# %% [markdown]
# ## Dataset Processing

# %%
import json 

# load data 
def load_data(dataset_path):
    with open(dataset_path, "r") as f:
        data = json.load(f)

    # convert lists into numpy arrays 
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    
    return inputs, targets

# %%
# split the data into train and test sets
inputs, targets = load_data(json_path)
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

input_train = torch.from_numpy(inputs_train).float()
input_test = torch.from_numpy(inputs_test).float()
target_train = torch.from_numpy(targets_train).long()
target_test = torch.from_numpy(targets_test).long()

train_dataset = TensorDataset(input_train, target_train)
test_dataset = TensorDataset(input_test, target_test)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ## Neural Network Architecture

# %%
# neural network architecture 
class MusicGenreClassifier(nn.Module):
    def __init__(self, time_steps, n_mfcc, num_classes=10):
        super().__init__()
        # build a model 
        self.net = nn.Sequential(
            # input layer 
            # convert everything into one vetor(batch, time_steps * n_mfcc)
            nn.Flatten(),
            nn.Linear(time_steps * n_mfcc, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )
    def forward(self, x):
        return self.net(x)

def train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50):
    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0
        for x_batch, y_batch in train_dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            # run forward pass 
            preds = model(x_batch)
            # run cross entropy loss 
            loss = loss_fn(preds, y_batch)
            # run backward pass 
            loss.backward()
            # update parameters 
            optimizer.step()

            # accumulate training loss 
            train_loss    += loss.item() * x_batch.size(0)
            
            # number of correct predictions in batch 
            train_correct += (preds.argmax(1) == y_batch).sum().item()

            # number of samples in the batch 
            train_total   += y_batch.size(0)

        # check the model accuracy once per epoch on the test data 
        test_loss, test_acc = evaluate(model, test_dataloader, loss_fn, device)

        print(
            f"Epoch {epoch + 1}/{epochs} | "
            f"train_loss: {train_loss / train_total:.4f} - train_acc: {train_correct / train_total:.4f} | "
            f"test_loss: {test_loss:.4f} - test_acc: {test_acc:.4f}"
        )
        
    print("---------------------------------------")
    print("Training Finished!\n")


def evaluate(model, dataloader, loss_fn, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            preds = model(x_batch)
            loss = loss_fn(preds, y_batch)
            total_loss += loss.item() * x_batch.size(0)
            correct    += (preds.argmax(1) == y_batch).sum().item()
            total      += y_batch.size(0)

    return total_loss / total, correct / total

# %%
# compile network 
model = MusicGenreClassifier(inputs.shape[1], inputs.shape[2]).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.CrossEntropyLoss()

# train network 
train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50)
# Out:
# Epoch 1/50 | train_loss: 1.6252 - train_acc: 0.4270 | test_loss: 1.4717 - test_acc: 0.4880
# Epoch 2/50 | train_loss: 1.2696 - train_acc: 0.5443 | test_loss: 1.3111 - test_acc: 0.5317
# Epoch 3/50 | train_loss: 1.1039 - train_acc: 0.6109 | test_loss: 1.2675 - test_acc: 0.5437
# Epoch 4/50 | train_loss: 0.9620 - train_acc: 0.6639 | test_loss: 1.2781 - test_acc: 0.5584
# Epoch 5/50 | train_loss: 0.8664 - train_acc: 0.6996 | test_loss: 1.2431 - test_acc: 0.5784
# Epoch 6/50 | train_loss: 0.7763 - train_acc: 0.7351 | test_loss: 1.2204 - test_acc: 0.5748
# Epoch 7/50 | train_loss: 0.6773 - train_acc: 0.7721 | test_loss: 1.1619 - test_acc: 0.6081
# Epoch 8/50 | train_loss: 0.5712 - train_acc: 0.8080 | test_loss: 1.2502 - test_acc: 0.5908
# Epoch 9/50 | train_loss: 0.4968 - train_acc: 0.8348 | test_loss: 1.2179 - test_acc: 0.6095
# Epoch 10/50 | train_loss: 0.4476 - train_acc: 0.8502 | test_loss: 1.1695 - test_acc: 0.6285
# Epoch 11/50 | train_loss: 0.3695 - train_acc: 0.8823 | test_loss: 1.1913 - test_acc: 0.6312
# Epoch 12/50 | train_loss: 0.3140 - train_acc: 0.9053 | test_loss: 1.3354 - test_acc: 0.5998
# Epoch 13/50 | train_loss: 0.2825 - train_acc: 0.9139 | test_loss: 1.2448 - test_acc: 0.6442
# Epoch 14/50 | train_loss: 0.2432 - train_acc: 0.9233 | test_loss: 1.2536 - test_acc: 0.6382
# Epoch 15/50 | train_loss: 0.2289 - train_acc: 0.9256 | test_loss: 1.3372 - test_acc: 0.6328
# Epoch 16/50 | train_loss: 0.1979 - train_acc: 0.9391 | test_loss: 1.3344 - test_acc: 0.6495
# Epoch 17/50 | train_loss: 0.1534 - train_acc: 0.9555 | test_loss: 1.4532 - test_acc: 0.6195
# Epoch 18/50 | train_loss: 0.1523 - train_acc: 0.9552 | test_loss: 1.4266 - test_acc: 0.6492
# Epoch 19/50 | train_loss: 0.1285 - train_acc: 0.9624 | test_loss: 1.4911 - test_acc: 0.6489
# Epoch 20/50 | train_loss: 0.1213 - train_acc: 0.9672 | test_loss: 1.5859 - test_acc: 0.6308
# Epoch 21/50 | train_loss: 0.1017 - train_acc: 0.9705 | test_loss: 1.4726 - test_acc: 0.6495
# Epoch 22/50 | train_loss: 0.0767 - train_acc: 0.9783 | test_loss: 1.4713 - test_acc: 0.6656
# Epoch 23/50 | train_loss: 0.0506 - train_acc: 0.9884 | test_loss: 1.5698 - test_acc: 0.6612
# Epoch 24/50 | train_loss: 0.1145 - train_acc: 0.9635 | test_loss: 1.5494 - test_acc: 0.6522
# Epoch 25/50 | train_loss: 0.0671 - train_acc: 0.9821 | test_loss: 1.6811 - test_acc: 0.6409
# Epoch 26/50 | train_loss: 0.1123 - train_acc: 0.9632 | test_loss: 1.5600 - test_acc: 0.6529
# Epoch 27/50 | train_loss: 0.0543 - train_acc: 0.9860 | test_loss: 1.7628 - test_acc: 0.6305
# Epoch 28/50 | train_loss: 0.0601 - train_acc: 0.9833 | test_loss: 1.6780 - test_acc: 0.6545
# Epoch 29/50 | train_loss: 0.0725 - train_acc: 0.9767 | test_loss: 1.7654 - test_acc: 0.6392
# Epoch 30/50 | train_loss: 0.0995 - train_acc: 0.9684 | test_loss: 1.8347 - test_acc: 0.6409
# Epoch 31/50 | train_loss: 0.0776 - train_acc: 0.9750 | test_loss: 1.6925 - test_acc: 0.6535
# Epoch 32/50 | train_loss: 0.0404 - train_acc: 0.9893 | test_loss: 1.7856 - test_acc: 0.6565
# Epoch 33/50 | train_loss: 0.0298 - train_acc: 0.9921 | test_loss: 1.8063 - test_acc: 0.6572
# Epoch 34/50 | train_loss: 0.0207 - train_acc: 0.9951 | test_loss: 1.8070 - test_acc: 0.6639
# Epoch 35/50 | train_loss: 0.0857 - train_acc: 0.9702 | test_loss: 2.0176 - test_acc: 0.6242
# Epoch 36/50 | train_loss: 0.0757 - train_acc: 0.9768 | test_loss: 1.9877 - test_acc: 0.6315
# Epoch 37/50 | train_loss: 0.0714 - train_acc: 0.9771 | test_loss: 2.2079 - test_acc: 0.6185
# Epoch 38/50 | train_loss: 0.0544 - train_acc: 0.9823 | test_loss: 1.8609 - test_acc: 0.6632
# Epoch 39/50 | train_loss: 0.0568 - train_acc: 0.9818 | test_loss: 1.8935 - test_acc: 0.6622
# Epoch 40/50 | train_loss: 0.0120 - train_acc: 0.9974 | test_loss: 1.8755 - test_acc: 0.6709
# Epoch 41/50 | train_loss: 0.0100 - train_acc: 0.9977 | test_loss: 1.9292 - test_acc: 0.6732
# Epoch 42/50 | train_loss: 0.0110 - train_acc: 0.9979 | test_loss: 1.8854 - test_acc: 0.6786
# Epoch 43/50 | train_loss: 0.0187 - train_acc: 0.9941 | test_loss: 2.1357 - test_acc: 0.6335
# Epoch 44/50 | train_loss: 0.2250 - train_acc: 0.9268 | test_loss: 1.8965 - test_acc: 0.6158
# Epoch 45/50 | train_loss: 0.0884 - train_acc: 0.9742 | test_loss: 1.9465 - test_acc: 0.6495
# Epoch 46/50 | train_loss: 0.0378 - train_acc: 0.9880 | test_loss: 1.8988 - test_acc: 0.6605
# Epoch 47/50 | train_loss: 0.0140 - train_acc: 0.9973 | test_loss: 2.2010 - test_acc: 0.6282
# Epoch 48/50 | train_loss: 0.0404 - train_acc: 0.9898 | test_loss: 2.0850 - test_acc: 0.6479
# Epoch 49/50 | train_loss: 0.0300 - train_acc: 0.9907 | test_loss: 2.0298 - test_acc: 0.6435
# Epoch 50/50 | train_loss: 0.0129 - train_acc: 0.9971 | test_loss: 1.8719 - test_acc: 0.6762
# ---------------------------------------
# Training Finished!

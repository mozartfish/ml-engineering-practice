# %% [markdown]
# ## Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import math 
from random import random 
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from pathlib import Path 
import librosa 
import json

# %% [markdown]
# ## Set up GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(f"Device: {device}")
# Out:
# Device: mps

# %% [markdown]
# ## Data

# %% [markdown]
# ### KAGGLE GTZAN Dataset

# %%
from dotenv import load_dotenv 
load_dotenv() 
import kagglehub 

download_path = Path(kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification"))

print(f"download path: {download_path}")
print(f"data contents: {list(download_path.iterdir())}")
# Out:
# download path: /Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1
# data contents: [PosixPath('/Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1/Data')]

# %% [markdown]
# ### Constants

# %%
SAMPLE_RATE = 22050
DURATION = 30  # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %% [markdown]
# ### MFCC Data Preprocessing

# %%
from tqdm import tqdm 

def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    # dictionary to store data
    data = {
        # genres
        "mapping": [],
        # mfcc vectors for each of the segments - the training inputs
        "mfcc": [],
        # the target variables
        "labels": [],
    }
 
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)  # 1.2 => 2
 
    # loop through all the genre folders (one level down from dataset_path)
    # sorted() makes the label order deterministic across machines
    genre_dirs = sorted(p for p in dataset_path.iterdir() if p.is_dir())
 
    for i, genre_dir in enumerate(genre_dirs):
        # save the semantic label (e.g. "blues")
        semantic_label = genre_dir.name
        data["mapping"].append(semantic_label)
        # .glob("*.wav") automatically skips hidden files like .DS_Store
        wav_files = sorted(genre_dir.glob("*.wav"))
 
        # process all wav files for current genre
        for file_path in tqdm(wav_files, desc=f"{semantic_label:10s}", leave=False):
            # some GTZAN files are corrupted (e.g. jazz.00054) - skip them
            try:
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
            except Exception as e:
                tqdm.write(f"Skipping corrupted file {file_path.name}")
                continue
 
            # process segments extracting mfcc and storing data
            # s - current segment we are in. slide to the right the number of samples per segment
            for s in range(num_segments):
                start_sample = num_samples_per_segment * s  # s=0 => 0
                end_sample = start_sample + num_samples_per_segment # s=0 => num_samples_per_segment

                # returns a matrix (mfcc, time)
                mfcc = librosa.feature.mfcc(
                    y=signal[start_sample:end_sample],
                    sr=sr,
                    n_fft=n_fft,
                    n_mfcc=n_mfcc,
                    hop_length=hop_length,
                )

                # convert to (time, mfcc) for deep learning 
                mfcc = mfcc.T
 
                # store mfcc for segment if it has the expected length
                if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i)
 
    # make sure the output directory exists before writing
    json_path.parent.mkdir(parents=True, exist_ok=True)
 
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
json_path = Path("data/mfcc_data.json")
dataset_path = download_path / "Data" / "genres_original"
save_mfcc(dataset_path, json_path, num_segments=10)
# Out:
# jazz      :  52%|████████████████████████████▌                          | 52/100 [00:01<00:01, 34.82it/s]/var/folders/73/y8z3_15n0c3fnwk5fkhj6ql40000gn/T/ipykernel_6456/752926399.py:32: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
# /Users/pranavrajan/Desktop/ml-engineering-practice/.venv/lib/python3.10/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# jazz      :  60%|█████████████████████████████████                      | 60/100 [00:04<00:06,  6.03it/s]
# Skipping corrupted file jazz.00054.wav

# %% [markdown]
# ## Dataset Processing

# %%
import json 

# load data 
def load_data(dataset_path):
    with open(dataset_path, "r") as f:
        data = json.load(f)

    # convert lists into numpy arrays 
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    
    return inputs, targets

# %%
# split the data into train and test sets
inputs, targets = load_data(json_path)
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

input_train = torch.from_numpy(inputs_train).float()
input_test = torch.from_numpy(inputs_test).float()
target_train = torch.from_numpy(targets_train).long()
target_test = torch.from_numpy(targets_test).long()

train_dataset = TensorDataset(input_train, target_train)
test_dataset = TensorDataset(input_test, target_test)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ## Neural Network Architecture

# %%
# neural network architecture 
class MusicGenreClassifier(nn.Module):
    def __init__(self, time_steps, n_mfcc, num_classes=10):
        super().__init__()
        # build a model 
        self.net = nn.Sequential(
            # input layer 
            # convert everything into one vetor(batch, time_steps * n_mfcc)
            nn.Flatten(),
            nn.Linear(time_steps * n_mfcc, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )
    def forward(self, x):
        return self.net(x)

def train(model, train_dataloader, val_dataloader, optimizer, loss_fn, device, epochs=50):
    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0
        for x_batch, y_batch in train_dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            # run forward pass 
            preds = model(x_batch)
            # run cross entropy loss 
            loss = loss_fn(preds, y_batch)
            # run backward pass 
            loss.backward()
            # update parameters 
            optimizer.step()

            # accumulate training loss 
            train_loss    += loss.item() * x_batch.size(0)
            
            # number of correct predictions in batch 
            train_correct += (preds.argmax(1) == y_batch).sum().item()

            # number of samples in the batch 
            train_total   += y_batch.size(0)

        # check the model accuracy once per epoch on the test data 
        val_loss, val_acc = evaluate(model, val_dataloader, loss_fn, device)

        print(
            f"Epoch {epoch + 1}/{epochs} | "
            f"train_loss: {train_loss / train_total:.4f} train_acc: {train_correct / train_total:.4f} | "
            f"val_loss: {val_loss:.4f} val_acc: {val_acc:.4f}"
        )
        
    print("---------------------------------------")
    print("Training Finished!\n")


def evaluate(model, dataloader, loss_fn, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            preds = model(x_batch)
            loss = loss_fn(preds, y_batch)
            total_loss += loss.item() * x_batch.size(0)
            correct    += (preds.argmax(1) == y_batch).sum().item()
            total      += y_batch.size(0)

    return total_loss / total, correct / total

# %%
# compile network 
model = MusicGenreClassifier(inputs.shape[1], inputs.shape[2]).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.CrossEntropyLoss()

# train network 
train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50)
# Out:
# Epoch 1/50 | train_loss: 1.6537 train_acc: 0.4146 | val_loss: 1.5779 val_acc: 0.4419
# Epoch 2/50 | train_loss: 1.2863 train_acc: 0.5439 | val_loss: 1.3603 val_acc: 0.5007
# Epoch 3/50 | train_loss: 1.1288 train_acc: 0.6016 | val_loss: 1.3195 val_acc: 0.5174
# Epoch 4/50 | train_loss: 0.9984 train_acc: 0.6565 | val_loss: 1.2485 val_acc: 0.5738
# Epoch 5/50 | train_loss: 0.8762 train_acc: 0.6961 | val_loss: 1.2472 val_acc: 0.5661
# Epoch 6/50 | train_loss: 0.7902 train_acc: 0.7285 | val_loss: 1.1672 val_acc: 0.5911
# Epoch 7/50 | train_loss: 0.6680 train_acc: 0.7744 | val_loss: 1.1555 val_acc: 0.6081
# Epoch 8/50 | train_loss: 0.5767 train_acc: 0.8109 | val_loss: 1.1556 val_acc: 0.6168
# Epoch 9/50 | train_loss: 0.5239 train_acc: 0.8288 | val_loss: 1.1229 val_acc: 0.6342
# Epoch 10/50 | train_loss: 0.4360 train_acc: 0.8577 | val_loss: 1.1634 val_acc: 0.6272
# Epoch 11/50 | train_loss: 0.3828 train_acc: 0.8838 | val_loss: 1.1819 val_acc: 0.6379
# Epoch 12/50 | train_loss: 0.3318 train_acc: 0.8931 | val_loss: 1.2241 val_acc: 0.6322
# Epoch 13/50 | train_loss: 0.2919 train_acc: 0.9064 | val_loss: 1.2279 val_acc: 0.6389
# Epoch 14/50 | train_loss: 0.2245 train_acc: 0.9326 | val_loss: 1.2480 val_acc: 0.6555
# Epoch 15/50 | train_loss: 0.2037 train_acc: 0.9395 | val_loss: 1.3303 val_acc: 0.6432
# Epoch 16/50 | train_loss: 0.2013 train_acc: 0.9373 | val_loss: 1.3562 val_acc: 0.6395
# Epoch 17/50 | train_loss: 0.1700 train_acc: 0.9496 | val_loss: 1.2898 val_acc: 0.6545
# Epoch 18/50 | train_loss: 0.1461 train_acc: 0.9571 | val_loss: 1.3724 val_acc: 0.6522
# Epoch 19/50 | train_loss: 0.1261 train_acc: 0.9651 | val_loss: 1.4398 val_acc: 0.6385
# Epoch 20/50 | train_loss: 0.1016 train_acc: 0.9720 | val_loss: 1.4154 val_acc: 0.6692
# Epoch 21/50 | train_loss: 0.0750 train_acc: 0.9818 | val_loss: 1.3874 val_acc: 0.6679
# Epoch 22/50 | train_loss: 0.0965 train_acc: 0.9724 | val_loss: 1.5022 val_acc: 0.6639
# Epoch 23/50 | train_loss: 0.0658 train_acc: 0.9834 | val_loss: 1.5844 val_acc: 0.6505
# Epoch 24/50 | train_loss: 0.1116 train_acc: 0.9668 | val_loss: 1.6939 val_acc: 0.6318
# Epoch 25/50 | train_loss: 0.0954 train_acc: 0.9698 | val_loss: 1.6480 val_acc: 0.6495
# Epoch 26/50 | train_loss: 0.1009 train_acc: 0.9684 | val_loss: 1.8433 val_acc: 0.6262
# Epoch 27/50 | train_loss: 0.0532 train_acc: 0.9860 | val_loss: 1.5657 val_acc: 0.6726
# Epoch 28/50 | train_loss: 0.0457 train_acc: 0.9874 | val_loss: 1.9093 val_acc: 0.6399
# Epoch 29/50 | train_loss: 0.0637 train_acc: 0.9824 | val_loss: 1.7164 val_acc: 0.6482
# Epoch 30/50 | train_loss: 0.0285 train_acc: 0.9930 | val_loss: 1.7859 val_acc: 0.6709
# Epoch 31/50 | train_loss: 0.0271 train_acc: 0.9931 | val_loss: 1.8294 val_acc: 0.6545
# Epoch 32/50 | train_loss: 0.0579 train_acc: 0.9833 | val_loss: 2.0664 val_acc: 0.6212
# Epoch 33/50 | train_loss: 0.1749 train_acc: 0.9456 | val_loss: 1.6595 val_acc: 0.6495
# Epoch 34/50 | train_loss: 0.0642 train_acc: 0.9791 | val_loss: 1.7692 val_acc: 0.6642
# Epoch 35/50 | train_loss: 0.0393 train_acc: 0.9890 | val_loss: 1.7719 val_acc: 0.6702
# Epoch 36/50 | train_loss: 0.0202 train_acc: 0.9964 | val_loss: 1.8178 val_acc: 0.6786
# Epoch 37/50 | train_loss: 0.0252 train_acc: 0.9928 | val_loss: 1.6839 val_acc: 0.6949
# Epoch 38/50 | train_loss: 0.0268 train_acc: 0.9923 | val_loss: 2.0107 val_acc: 0.6399
# Epoch 39/50 | train_loss: 0.1615 train_acc: 0.9455 | val_loss: 1.7332 val_acc: 0.6539
# Epoch 40/50 | train_loss: 0.0408 train_acc: 0.9886 | val_loss: 1.8665 val_acc: 0.6666
# Epoch 41/50 | train_loss: 0.0376 train_acc: 0.9900 | val_loss: 1.8364 val_acc: 0.6545
# Epoch 42/50 | train_loss: 0.0390 train_acc: 0.9881 | val_loss: 1.7882 val_acc: 0.6772
# Epoch 43/50 | train_loss: 0.0115 train_acc: 0.9980 | val_loss: 1.8530 val_acc: 0.6812
# Epoch 44/50 | train_loss: 0.0821 train_acc: 0.9758 | val_loss: 1.8740 val_acc: 0.6499
# Epoch 45/50 | train_loss: 0.0644 train_acc: 0.9804 | val_loss: 1.8173 val_acc: 0.6786
# Epoch 46/50 | train_loss: 0.0103 train_acc: 0.9979 | val_loss: 1.8022 val_acc: 0.6893
# Epoch 47/50 | train_loss: 0.0098 train_acc: 0.9970 | val_loss: 1.8681 val_acc: 0.6866
# Epoch 48/50 | train_loss: 0.0081 train_acc: 0.9983 | val_loss: 1.8823 val_acc: 0.6896
# Epoch 49/50 | train_loss: 0.0039 train_acc: 0.9993 | val_loss: 1.9097 val_acc: 0.6969
# Epoch 50/50 | train_loss: 0.0081 train_acc: 0.9980 | val_loss: 2.0218 val_acc: 0.6816
# ---------------------------------------
# Training Finished!

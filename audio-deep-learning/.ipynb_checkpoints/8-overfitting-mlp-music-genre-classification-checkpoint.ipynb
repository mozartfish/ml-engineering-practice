# %% [markdown]
# ## Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import math 
from random import random 
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from pathlib import Path 
import librosa 
import json 
from collections import defaultdict

# %% [markdown]
# ## Set up GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(f"Device: {device}")
# Out:
# Device: mps

# %% [markdown]
# ## Data

# %% [markdown]
# ### KAGGLE GTZAN Dataset

# %%
from dotenv import load_dotenv 
load_dotenv() 
import kagglehub 

download_path = Path(kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification"))

print(f"download path: {download_path}")
print(f"data contents: {list(download_path.iterdir())}")
# Out:
# download path: /Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1
# data contents: [PosixPath('/Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1/Data')]

# %% [markdown]
# ### Constants

# %%
SAMPLE_RATE = 22050
DURATION = 30  # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %% [markdown]
# ### MFCC Data Preprocessing

# %%
from tqdm import tqdm 

def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    # dictionary to store data
    data = {
        # genres
        "mapping": [],
        # mfcc vectors for each of the segments - the training inputs
        "mfcc": [],
        # the target variables
        "labels": [],
    }
 
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)  # 1.2 => 2
 
    # loop through all the genre folders (one level down from dataset_path)
    # sorted() makes the label order deterministic across machines
    genre_dirs = sorted(p for p in dataset_path.iterdir() if p.is_dir())
 
    for i, genre_dir in enumerate(genre_dirs):
        # save the semantic label (e.g. "blues")
        semantic_label = genre_dir.name
        data["mapping"].append(semantic_label)
        # .glob("*.wav") automatically skips hidden files like .DS_Store
        wav_files = sorted(genre_dir.glob("*.wav"))
 
        # process all wav files for current genre
        for file_path in tqdm(wav_files, desc=f"{semantic_label:10s}", leave=True):
            # some GTZAN files are corrupted (e.g. jazz.00054) - skip them
            try:
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
            except Exception as e:
                tqdm.write(f"Skipping corrupted file {file_path.name}")
                continue
 
            # process segments extracting mfcc and storing data
            # s - current segment we are in. slide to the right the number of samples per segment
            for s in range(num_segments):
                start_sample = num_samples_per_segment * s  # s=0 => 0
                end_sample = start_sample + num_samples_per_segment # s=0 => num_samples_per_segment

                # returns a matrix (mfcc, time)
                mfcc = librosa.feature.mfcc(
                    y=signal[start_sample:end_sample],
                    sr=sr,
                    n_fft=n_fft,
                    n_mfcc=n_mfcc,
                    hop_length=hop_length,
                )

                # convert to (time, mfcc) for deep learning 
                mfcc = mfcc.T
 
                # store mfcc for segment if it has the expected length
                if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i)
 
    # make sure the output directory exists before writing
    json_path.parent.mkdir(parents=True, exist_ok=True)
 
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
json_path = Path("data/mfcc_data.json")
dataset_path = download_path / "Data" / "genres_original"
save_mfcc(dataset_path, json_path, num_segments=10)
# Out:
# blues     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.47it/s]
# classical : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 44.44it/s]
# country   : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 47.71it/s]
# disco     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 41.64it/s]
# hiphop    : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.40it/s]
# jazz      :  54%|████████████████████████████                        | 54/100 [00:01<00:00, 49.68it/s]/var/folders/73/y8z3_15n0c3fnwk5fkhj6ql40000gn/T/ipykernel_10330/2706401927.py:32: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
# /Users/pranavrajan/Desktop/ml-engineering-practice/.venv/lib/python3.10/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# jazz      :  64%|█████████████████████████████████▎                  | 64/100 [00:03<00:03,  9.03it/s]
# Skipping corrupted file jazz.00054.wav
# jazz      : 100%|███████████████████████████████████████████████████| 100/100 [00:04<00:00, 21.82it/s]
# metal     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 45.07it/s]
# pop       : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.34it/s]
# reggae    : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 49.46it/s]
# rock      : 100%|███████████████████████████████████████████████████| 100/100 [00:01<00:00, 50.98it/s]

# %% [markdown]
# ## Dataset Processing

# %%
import json 

# load data 
def load_data(dataset_path):
    with open(dataset_path, "r") as f:
        data = json.load(f)

    # convert lists into numpy arrays 
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    
    return inputs, targets

# %%
# split the data into train and test sets
inputs, targets = load_data(json_path)
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

input_train = torch.from_numpy(inputs_train).float()
input_test = torch.from_numpy(inputs_test).float()
target_train = torch.from_numpy(targets_train).long()
target_test = torch.from_numpy(targets_test).long()

train_dataset = TensorDataset(input_train, target_train)
test_dataset = TensorDataset(input_test, target_test)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ## Neural Network Architecture - Dropout + Regularization

# %%
# neural network architecture 
class MusicGenreClassifier(nn.Module):
    def __init__(self, time_steps, n_mfcc, num_classes=10, dropout_prob=0.3):
        super().__init__()
        # build a model 
        self.net = nn.Sequential(
            # input layer 
            nn.Flatten(),

            # 1st layer 
            nn.Linear(time_steps * n_mfcc, 512),
            nn.ReLU(),
            nn.Dropout(dropout_prob), 

            # 2nd layer 
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(dropout_prob), 

            # 3rd layer 
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(dropout_prob), 

            # output layer 
            nn.Linear(64, num_classes)
        )
    def forward(self, x):
        return self.net(x)

def train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50):
    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0
        for x_batch, y_batch in train_dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            # run forward pass 
            preds = model(x_batch)
            # run cross entropy loss 
            loss = loss_fn(preds, y_batch)
            # run backward pass 
            loss.backward()
            # update parameters 
            optimizer.step()

            # accumulate training loss 
            train_loss    += loss.item() * x_batch.size(0)
            
            # number of correct predictions in batch 
            train_correct += (preds.argmax(1) == y_batch).sum().item()

            # number of samples in the batch 
            train_total += y_batch.size(0)

        # check the model accuracy once per epoch on the test data 
        test_loss, test_acc = evaluate(model, test_dataloader, loss_fn, device)

        # update the training statistics 
        history["train_loss"].append(train_loss / train_total)
        history["train_acc"].append(train_correct / train_total)
        history["test_loss"].append(test_loss)
        history["test_acc"].append(test_acc)

        print(
            f"Epoch {epoch + 1}/{epochs} | "
            f"train_loss: {train_loss / train_total:.4f} - train_acc: {train_correct / train_total:.4f} | "
            f"test_loss: {test_loss:.4f} - test_acc: {test_acc:.4f}"
        )
        
    print("---------------------------------------")
    print("Training Finished!\n")


def evaluate(model, dataloader, loss_fn, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            preds = model(x_batch)
            loss = loss_fn(preds, y_batch)
            total_loss += loss.item() * x_batch.size(0)
            correct    += (preds.argmax(1) == y_batch).sum().item()
            total      += y_batch.size(0)

    return total_loss / total, correct / total

# %%
# compile network 
model = MusicGenreClassifier(inputs.shape[1], inputs.shape[2]).to(device)
# weight_decay = l2 regularization in pytorch 
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-3)
loss_fn = nn.CrossEntropyLoss()

# train network 
history = defaultdict(list)
train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50)
# Out:
# Epoch 1/50 | train_loss: 2.3481 - train_acc: 0.2346 | test_loss: 1.7997 - test_acc: 0.3795
# Epoch 2/50 | train_loss: 1.8619 - train_acc: 0.3316 | test_loss: 1.6234 - test_acc: 0.4209
# Epoch 3/50 | train_loss: 1.7271 - train_acc: 0.3781 | test_loss: 1.5673 - test_acc: 0.4332
# Epoch 4/50 | train_loss: 1.6217 - train_acc: 0.4117 | test_loss: 1.4706 - test_acc: 0.4880
# Epoch 5/50 | train_loss: 1.5769 - train_acc: 0.4345 | test_loss: 1.4538 - test_acc: 0.4877
# Epoch 6/50 | train_loss: 1.5141 - train_acc: 0.4638 | test_loss: 1.4247 - test_acc: 0.5050
# Epoch 7/50 | train_loss: 1.4480 - train_acc: 0.4783 | test_loss: 1.3380 - test_acc: 0.5290
# Epoch 8/50 | train_loss: 1.4099 - train_acc: 0.4967 | test_loss: 1.3498 - test_acc: 0.5164
# Epoch 9/50 | train_loss: 1.3507 - train_acc: 0.5160 | test_loss: 1.3120 - test_acc: 0.5457
# Epoch 10/50 | train_loss: 1.3221 - train_acc: 0.5289 | test_loss: 1.3002 - test_acc: 0.5567
# Epoch 11/50 | train_loss: 1.2800 - train_acc: 0.5458 | test_loss: 1.2397 - test_acc: 0.5614
# Epoch 12/50 | train_loss: 1.2522 - train_acc: 0.5629 | test_loss: 1.2361 - test_acc: 0.5624
# Epoch 13/50 | train_loss: 1.2095 - train_acc: 0.5722 | test_loss: 1.2454 - test_acc: 0.5641
# Epoch 14/50 | train_loss: 1.1616 - train_acc: 0.5926 | test_loss: 1.2396 - test_acc: 0.5744
# Epoch 15/50 | train_loss: 1.1267 - train_acc: 0.5993 | test_loss: 1.2290 - test_acc: 0.5728
# Epoch 16/50 | train_loss: 1.1121 - train_acc: 0.6066 | test_loss: 1.2466 - test_acc: 0.5724
# Epoch 17/50 | train_loss: 1.0578 - train_acc: 0.6338 | test_loss: 1.2348 - test_acc: 0.5758
# Epoch 18/50 | train_loss: 1.0389 - train_acc: 0.6318 | test_loss: 1.1886 - test_acc: 0.5911
# Epoch 19/50 | train_loss: 0.9947 - train_acc: 0.6524 | test_loss: 1.1722 - test_acc: 0.5928
# Epoch 20/50 | train_loss: 0.9656 - train_acc: 0.6642 | test_loss: 1.2123 - test_acc: 0.5861
# Epoch 21/50 | train_loss: 0.9303 - train_acc: 0.6790 | test_loss: 1.1894 - test_acc: 0.5968
# Epoch 22/50 | train_loss: 0.9188 - train_acc: 0.6823 | test_loss: 1.1389 - test_acc: 0.6061
# Epoch 23/50 | train_loss: 0.8762 - train_acc: 0.7023 | test_loss: 1.1524 - test_acc: 0.6265
# Epoch 24/50 | train_loss: 0.8470 - train_acc: 0.7031 | test_loss: 1.1885 - test_acc: 0.6111
# Epoch 25/50 | train_loss: 0.8490 - train_acc: 0.7102 | test_loss: 1.1956 - test_acc: 0.6145
# Epoch 26/50 | train_loss: 0.8076 - train_acc: 0.7190 | test_loss: 1.1551 - test_acc: 0.6238
# Epoch 27/50 | train_loss: 0.7765 - train_acc: 0.7375 | test_loss: 1.1469 - test_acc: 0.6232
# Epoch 28/50 | train_loss: 0.7335 - train_acc: 0.7504 | test_loss: 1.2231 - test_acc: 0.6108
# Epoch 29/50 | train_loss: 0.7375 - train_acc: 0.7495 | test_loss: 1.1928 - test_acc: 0.6275
# Epoch 30/50 | train_loss: 0.7169 - train_acc: 0.7495 | test_loss: 1.1589 - test_acc: 0.6335
# Epoch 31/50 | train_loss: 0.7018 - train_acc: 0.7592 | test_loss: 1.1509 - test_acc: 0.6312
# Epoch 32/50 | train_loss: 0.6986 - train_acc: 0.7579 | test_loss: 1.1929 - test_acc: 0.6182
# Epoch 33/50 | train_loss: 0.6564 - train_acc: 0.7737 | test_loss: 1.1564 - test_acc: 0.6365
# Epoch 34/50 | train_loss: 0.6316 - train_acc: 0.7785 | test_loss: 1.2124 - test_acc: 0.6385
# Epoch 35/50 | train_loss: 0.6199 - train_acc: 0.7856 | test_loss: 1.2477 - test_acc: 0.6355
# Epoch 36/50 | train_loss: 0.5966 - train_acc: 0.7964 | test_loss: 1.2609 - test_acc: 0.6188
# Epoch 37/50 | train_loss: 0.5893 - train_acc: 0.8019 | test_loss: 1.2070 - test_acc: 0.6442
# Epoch 38/50 | train_loss: 0.5728 - train_acc: 0.8086 | test_loss: 1.2115 - test_acc: 0.6462
# Epoch 39/50 | train_loss: 0.5723 - train_acc: 0.8054 | test_loss: 1.2296 - test_acc: 0.6362
# Epoch 40/50 | train_loss: 0.5251 - train_acc: 0.8200 | test_loss: 1.2119 - test_acc: 0.6515
# Epoch 41/50 | train_loss: 0.5262 - train_acc: 0.8180 | test_loss: 1.2892 - test_acc: 0.6318
# Epoch 42/50 | train_loss: 0.5438 - train_acc: 0.8155 | test_loss: 1.2318 - test_acc: 0.6485
# Epoch 43/50 | train_loss: 0.5258 - train_acc: 0.8240 | test_loss: 1.2258 - test_acc: 0.6382
# Epoch 44/50 | train_loss: 0.5145 - train_acc: 0.8258 | test_loss: 1.2494 - test_acc: 0.6375
# Epoch 45/50 | train_loss: 0.4758 - train_acc: 0.8402 | test_loss: 1.2795 - test_acc: 0.6382
# Epoch 46/50 | train_loss: 0.4678 - train_acc: 0.8422 | test_loss: 1.2307 - test_acc: 0.6599
# Epoch 47/50 | train_loss: 0.4596 - train_acc: 0.8382 | test_loss: 1.2389 - test_acc: 0.6452
# Epoch 48/50 | train_loss: 0.4427 - train_acc: 0.8492 | test_loss: 1.2414 - test_acc: 0.6505
# Epoch 49/50 | train_loss: 0.4558 - train_acc: 0.8429 | test_loss: 1.3818 - test_acc: 0.6379
# Epoch 50/50 | train_loss: 0.4320 - train_acc: 0.8589 | test_loss: 1.3149 - test_acc: 0.6382
# ---------------------------------------
# Training Finished!

# %% [markdown]
# ## Overfitting Debugging

# %%
def plot_history(history):
    fig, axs = plt.subplots(2, figsize=(10, 8))
    
    # create accuracy subplot 
    axs[0].plot(history["train_acc"], label="train accuracy")
    axs[0].plot(history["test_acc"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="best")
    axs[0].set_title("Accuracy eval")

    # create error subplot 
    axs[1].plot(history["train_loss"], label="train error")
    axs[1].plot(history["test_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="best")
    axs[1].set_title("Error eval")

    fig.tight_layout()
    plt.show()

# %%
# plot accuracy and error over the epochs 
plot_history(history)

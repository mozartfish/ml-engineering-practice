# %% [markdown]
# ## Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import math 
from random import random 
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from pathlib import Path 
import librosa 
import json 
from collections import defaultdict

# %% [markdown]
# ## Set up GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(f"Device: {device}")
# Out:
# Device: mps

# %% [markdown]
# ## Data

# %% [markdown]
# ### KAGGLE GTZAN Dataset

# %%
from dotenv import load_dotenv 
load_dotenv() 
import kagglehub 

download_path = Path(kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification"))

print(f"download path: {download_path}")
print(f"data contents: {list(download_path.iterdir())}")
# Out:
# download path: /Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1
# data contents: [PosixPath('/Users/pranavrajan/.cache/kagglehub/datasets/andradaolteanu/gtzan-dataset-music-genre-classification/versions/1/Data')]

# %% [markdown]
# ### Constants

# %%
SAMPLE_RATE = 22050
DURATION = 30  # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %% [markdown]
# ### MFCC Data Preprocessing

# %%
from tqdm import tqdm 

def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    # dictionary to store data
    data = {
        # genres
        "mapping": [],
        # mfcc vectors for each of the segments - the training inputs
        "mfcc": [],
        # the target variables
        "labels": [],
    }
 
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)  # 1.2 => 2
 
    # loop through all the genre folders (one level down from dataset_path)
    # sorted() makes the label order deterministic across machines
    genre_dirs = sorted(p for p in dataset_path.iterdir() if p.is_dir())
 
    for i, genre_dir in enumerate(genre_dirs):
        # save the semantic label (e.g. "blues")
        semantic_label = genre_dir.name
        data["mapping"].append(semantic_label)
        # .glob("*.wav") automatically skips hidden files like .DS_Store
        wav_files = sorted(genre_dir.glob("*.wav"))
 
        # process all wav files for current genre
        for file_path in tqdm(wav_files, desc=f"{semantic_label:10s}", leave=True):
            # some GTZAN files are corrupted (e.g. jazz.00054) - skip them
            try:
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
            except Exception as e:
                tqdm.write(f"Skipping corrupted file {file_path.name}")
                continue
 
            # process segments extracting mfcc and storing data
            # s - current segment we are in. slide to the right the number of samples per segment
            for s in range(num_segments):
                start_sample = num_samples_per_segment * s  # s=0 => 0
                end_sample = start_sample + num_samples_per_segment # s=0 => num_samples_per_segment

                # returns a matrix (mfcc, time)
                mfcc = librosa.feature.mfcc(
                    y=signal[start_sample:end_sample],
                    sr=sr,
                    n_fft=n_fft,
                    n_mfcc=n_mfcc,
                    hop_length=hop_length,
                )

                # convert to (time, mfcc) for deep learning 
                mfcc = mfcc.T
 
                # store mfcc for segment if it has the expected length
                if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                    data["mfcc"].append(mfcc.tolist())
                    data["labels"].append(i)
 
    # make sure the output directory exists before writing
    json_path.parent.mkdir(parents=True, exist_ok=True)
 
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
json_path = Path("data/mfcc_data.json")
dataset_path = download_path / "Data" / "genres_original"
save_mfcc(dataset_path, json_path, num_segments=10)
# Out:
# blues     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 37.96it/s]
# classical : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 48.03it/s]
# country   : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.68it/s]
# disco     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.51it/s]
# hiphop    : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 49.16it/s]
# jazz      :  53%|███████████████████████████▌                        | 53/100 [00:01<00:00, 49.97it/s]/var/folders/73/y8z3_15n0c3fnwk5fkhj6ql40000gn/T/ipykernel_10016/2706401927.py:32: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
# /Users/pranavrajan/Desktop/ml-engineering-practice/.venv/lib/python3.10/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# jazz      :  58%|██████████████████████████████▏                     | 58/100 [00:01<00:01, 37.16it/s]
# Skipping corrupted file jazz.00054.wav
# jazz      : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 44.56it/s]
# metal     : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 49.41it/s]
# pop       : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 45.64it/s]
# reggae    : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 46.43it/s]
# rock      : 100%|███████████████████████████████████████████████████| 100/100 [00:02<00:00, 45.98it/s]

# %% [markdown]
# ## Dataset Processing

# %%
import json 

# load data 
def load_data(dataset_path):
    with open(dataset_path, "r") as f:
        data = json.load(f)

    # convert lists into numpy arrays 
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    
    return inputs, targets

# %%
# split the data into train and test sets
inputs, targets = load_data(json_path)
inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)

input_train = torch.from_numpy(inputs_train).float()
input_test = torch.from_numpy(inputs_test).float()
target_train = torch.from_numpy(targets_train).long()
target_test = torch.from_numpy(targets_test).long()

train_dataset = TensorDataset(input_train, target_train)
test_dataset = TensorDataset(input_test, target_test)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ## Neural Network Architecture - Dropout + Regularization

# %%
# neural network architecture 
class MusicGenreClassifier(nn.Module):
    def __init__(self, time_steps, n_mfcc, num_classes=10, dropout_prob=0.3):
        super().__init__()
        # build a model 
        self.net = nn.Sequential(
            # input layer 
            nn.Flatten(),

            # 1st layer 
            nn.Linear(time_steps * n_mfcc, 512),
            nn.ReLU(),
            nn.Dropout(dropout_prob), 

            # 2nd layer 
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(dropout_prob), 

            # 3rd layer 
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(dropout_prob), 

            # output layer 
            nn.Linear(64, num_classes)
        )
    def forward(self, x):
        return self.net(x)

def train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50):
    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0
        for x_batch, y_batch in train_dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            # run forward pass 
            preds = model(x_batch)
            # run cross entropy loss 
            loss = loss_fn(preds, y_batch)
            # run backward pass 
            loss.backward()
            # update parameters 
            optimizer.step()

            # accumulate training loss 
            train_loss    += loss.item() * x_batch.size(0)
            
            # number of correct predictions in batch 
            train_correct += (preds.argmax(1) == y_batch).sum().item()

            # number of samples in the batch 
            train_total += y_batch.size(0)

        # check the model accuracy once per epoch on the test data 
        test_loss, test_acc = evaluate(model, test_dataloader, loss_fn, device)

        # update the training statistics 
        history["train_loss"].append(train_loss / train_total)
        history["train_acc"].append(train_correct / train_total)
        history["test_loss"].append(test_loss)
        history["test_acc"].append(test_acc)

        print(
            f"Epoch {epoch + 1}/{epochs} | "
            f"train_loss: {train_loss / train_total:.4f} - train_acc: {train_correct / train_total:.4f} | "
            f"test_loss: {test_loss:.4f} - test_acc: {test_acc:.4f}"
        )
        
    print("---------------------------------------")
    print("Training Finished!\n")


def evaluate(model, dataloader, loss_fn, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            preds = model(x_batch)
            loss = loss_fn(preds, y_batch)
            total_loss += loss.item() * x_batch.size(0)
            correct    += (preds.argmax(1) == y_batch).sum().item()
            total      += y_batch.size(0)

    return total_loss / total, correct / total

# %%
# compile network 
model = MusicGenreClassifier(inputs.shape[1], inputs.shape[2]).to(device)
# weight_decay = l2 regularization in pytorch 
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-3)
loss_fn = nn.CrossEntropyLoss()

# train network 
history = defaultdict(list)
train(model, train_dataloader, test_dataloader, optimizer, loss_fn, device, epochs=50)
# Out:
# Epoch 1/50 | train_loss: 2.2090 - train_acc: 0.2584 | test_loss: 1.7078 - test_acc: 0.3882
# Epoch 2/50 | train_loss: 1.8189 - train_acc: 0.3406 | test_loss: 1.5554 - test_acc: 0.4376
# Epoch 3/50 | train_loss: 1.7068 - train_acc: 0.3795 | test_loss: 1.4813 - test_acc: 0.4796
# Epoch 4/50 | train_loss: 1.6185 - train_acc: 0.4155 | test_loss: 1.4424 - test_acc: 0.5020
# Epoch 5/50 | train_loss: 1.5427 - train_acc: 0.4403 | test_loss: 1.4001 - test_acc: 0.5030
# Epoch 6/50 | train_loss: 1.4870 - train_acc: 0.4628 | test_loss: 1.3549 - test_acc: 0.5270
# Epoch 7/50 | train_loss: 1.4512 - train_acc: 0.4878 | test_loss: 1.3215 - test_acc: 0.5304
# Epoch 8/50 | train_loss: 1.4225 - train_acc: 0.4948 | test_loss: 1.3028 - test_acc: 0.5384
# Epoch 9/50 | train_loss: 1.3495 - train_acc: 0.5256 | test_loss: 1.3038 - test_acc: 0.5437
# Epoch 10/50 | train_loss: 1.3060 - train_acc: 0.5362 | test_loss: 1.2584 - test_acc: 0.5564
# Epoch 11/50 | train_loss: 1.2824 - train_acc: 0.5458 | test_loss: 1.2251 - test_acc: 0.5758
# Epoch 12/50 | train_loss: 1.2554 - train_acc: 0.5557 | test_loss: 1.2263 - test_acc: 0.5628
# Epoch 13/50 | train_loss: 1.1974 - train_acc: 0.5755 | test_loss: 1.2094 - test_acc: 0.5788
# Epoch 14/50 | train_loss: 1.1677 - train_acc: 0.5943 | test_loss: 1.2166 - test_acc: 0.5708
# Epoch 15/50 | train_loss: 1.1428 - train_acc: 0.5948 | test_loss: 1.1923 - test_acc: 0.5848
# Epoch 16/50 | train_loss: 1.0965 - train_acc: 0.6140 | test_loss: 1.2154 - test_acc: 0.5711
# Epoch 17/50 | train_loss: 1.0556 - train_acc: 0.6312 | test_loss: 1.1724 - test_acc: 0.5965
# Epoch 18/50 | train_loss: 1.0228 - train_acc: 0.6426 | test_loss: 1.1698 - test_acc: 0.5938
# Epoch 19/50 | train_loss: 0.9998 - train_acc: 0.6489 | test_loss: 1.1284 - test_acc: 0.6055
# Epoch 20/50 | train_loss: 0.9746 - train_acc: 0.6557 | test_loss: 1.1600 - test_acc: 0.6048
# Epoch 21/50 | train_loss: 0.9337 - train_acc: 0.6674 | test_loss: 1.1422 - test_acc: 0.6128
# Epoch 22/50 | train_loss: 0.9228 - train_acc: 0.6785 | test_loss: 1.1591 - test_acc: 0.6065
# Epoch 23/50 | train_loss: 0.8792 - train_acc: 0.6906 | test_loss: 1.1472 - test_acc: 0.6048
# Epoch 24/50 | train_loss: 0.8645 - train_acc: 0.6969 | test_loss: 1.1274 - test_acc: 0.6215
# Epoch 25/50 | train_loss: 0.8160 - train_acc: 0.7206 | test_loss: 1.1531 - test_acc: 0.6135
# Epoch 26/50 | train_loss: 0.8080 - train_acc: 0.7157 | test_loss: 1.1488 - test_acc: 0.6178
# Epoch 27/50 | train_loss: 0.7726 - train_acc: 0.7289 | test_loss: 1.1661 - test_acc: 0.6228
# Epoch 28/50 | train_loss: 0.7495 - train_acc: 0.7399 | test_loss: 1.1660 - test_acc: 0.6288
# Epoch 29/50 | train_loss: 0.7389 - train_acc: 0.7429 | test_loss: 1.1449 - test_acc: 0.6282
# Epoch 30/50 | train_loss: 0.7074 - train_acc: 0.7569 | test_loss: 1.1443 - test_acc: 0.6475
# Epoch 31/50 | train_loss: 0.7112 - train_acc: 0.7482 | test_loss: 1.1938 - test_acc: 0.6168
# Epoch 32/50 | train_loss: 0.6842 - train_acc: 0.7638 | test_loss: 1.1655 - test_acc: 0.6312
# Epoch 33/50 | train_loss: 0.6624 - train_acc: 0.7672 | test_loss: 1.2813 - test_acc: 0.6065
# Epoch 34/50 | train_loss: 0.6350 - train_acc: 0.7767 | test_loss: 1.1490 - test_acc: 0.6358
# Epoch 35/50 | train_loss: 0.6209 - train_acc: 0.7831 | test_loss: 1.2131 - test_acc: 0.6355
# Epoch 36/50 | train_loss: 0.5861 - train_acc: 0.7947 | test_loss: 1.1849 - test_acc: 0.6462
# Epoch 37/50 | train_loss: 0.5929 - train_acc: 0.8029 | test_loss: 1.2351 - test_acc: 0.6245
# Epoch 38/50 | train_loss: 0.5719 - train_acc: 0.8003 | test_loss: 1.2188 - test_acc: 0.6382
# Epoch 39/50 | train_loss: 0.5662 - train_acc: 0.8001 | test_loss: 1.2372 - test_acc: 0.6265
# Epoch 40/50 | train_loss: 0.5423 - train_acc: 0.8159 | test_loss: 1.2091 - test_acc: 0.6322
# Epoch 41/50 | train_loss: 0.5160 - train_acc: 0.8190 | test_loss: 1.2281 - test_acc: 0.6422
# Epoch 42/50 | train_loss: 0.5220 - train_acc: 0.8189 | test_loss: 1.1931 - test_acc: 0.6519
# Epoch 43/50 | train_loss: 0.5142 - train_acc: 0.8269 | test_loss: 1.2644 - test_acc: 0.6355
# Epoch 44/50 | train_loss: 0.4988 - train_acc: 0.8260 | test_loss: 1.2525 - test_acc: 0.6509
# Epoch 45/50 | train_loss: 0.4801 - train_acc: 0.8375 | test_loss: 1.2536 - test_acc: 0.6539
# Epoch 46/50 | train_loss: 0.4956 - train_acc: 0.8346 | test_loss: 1.3030 - test_acc: 0.6419
# Epoch 47/50 | train_loss: 0.4772 - train_acc: 0.8405 | test_loss: 1.2791 - test_acc: 0.6529
# Epoch 48/50 | train_loss: 0.4495 - train_acc: 0.8484 | test_loss: 1.3063 - test_acc: 0.6532
# Epoch 49/50 | train_loss: 0.4414 - train_acc: 0.8482 | test_loss: 1.2631 - test_acc: 0.6515
# Epoch 50/50 | train_loss: 0.4462 - train_acc: 0.8501 | test_loss: 1.3479 - test_acc: 0.6422
# ---------------------------------------
# Training Finished!

# %% [markdown]
# ## Overfitting Debugging

# %%
def plot_history(history):
    fig, axs = plt.subplots(2, figsize=(10, 8))
    
    # create accuracy subplot 
    axs[0].plot(history["train_acc"], label="train accuracy")
    axs[0].plot(history["test_acc"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="best")
    axs[0].set_title("Accuracy eval")

    # create error subplot 
    axs[1].plot(history["train_loss"], label="train error")
    axs[1].plot(history["test_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="best")
    axs[1].set_title("Error eval")

    fig.tight_layout()
    plt.show()

# %%
# plot accuracy and error over the epochs 
plot_history(history)
